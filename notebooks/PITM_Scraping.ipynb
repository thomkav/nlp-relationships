# %% [markdown]
# ## Imports

# %%
from bs4 import BeautifulSoup
import requests
import re
import sys
import string
import json
from ast import literal_eval
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from dateutil.parser import parse
import pdb
from pymongo import MongoClient
from pprint import pprint

# %% [markdown]
# ## Initialize Mongodb

# %%
client = MongoClient()
db = client.polymedia
print("Collections: ",db.list_collection_names())
# Out:
# Collections:  ['subreddit_polyamory', 'temp', 'pitm', 'test']

# %% [markdown]
# ## Scraping Utility Functions

# %%
def escape_ansi(line):
    ansi_escape = re.compile(r'(\x9B|\x1B\[)[0-?]*[ -\/]*[@-~]+')
    return ansi_escape.sub('', line)


def make_soup(url):
    webpage_response = requests.get(url)
    return BeautifulSoup(webpage_response.content, 'html.parser')


def get_all_a_hrefs(soup, selector=''):
    """
    Grabs all href attribute values from a tags
    contained inside given selector.
    """
    links = []
    if len(selector) > 0:
        prefix = selector + ' '
    else:
        prefix = ''
    for a in soup.select(prefix + 'a', href=True):
        links += [a['href']]
    return list(set(links))


def is_link_date_archive(link):
    """
    Identifies links with potential date value in url path.
    """
    # print(link)
    # print(re.search('.+\/[0-9]{4}\/[0-9]{2}\/', link))
    if re.search('.+[0-9]{4}/[0-9]{2}.+', link) is None:
        return False
    else:
        return True


def list_outbound_links(page_url, domain):
    soup = make_soup(page_url)
    links = get_all_a_hrefs(soup)
    return [link for link in links if not((re.search('.+domain.+', link)))]

def get_post_permalinks(archive_url):
    soup = make_soup(archive_url)
    permalinks = soup.select('a[title="permanent link"]')
    return [p['href'] for p in permalinks]

def scrape_posts(permalinks):
    
    cols = []

    # Iterate through posts and create dictionary:
    for p in permalinks:
        
        soup = make_soup(p)
        date_header = soup.select('.date-header')[0]
        post = soup.select('.post')[0]
        
        try:
            comments = soup.select('#comments')[0]
            num_comments = int(comments.select('h4')[0].get_text().split()[0])
            comment_blocks = [c.text.strip()
                      for c in post.find_all(".comment-body")]
        except:
            num_comments = 0
            comment_blocks = []

        post_col = {}

        # Save raw HTML for later, just in case:
        post_col['raw_post_html'] = str(post)
        post_col['raw_comments_html'] = str(comments)
        
        # Save comments:
        post_col['comments'] = comment_blocks
        
        # Post meta:
        post_col['num_comments'] = num_comments
        post_col['post_date_string'] = date_header.get_text()
        post_col['post_date'] = parse(date_header.get_text())
        post_col['post_title'] = post.select('h3.post-title')[0].get_text().strip()

        # Collect all blockquotes from news sources:
        quotes = post.find_all("blockquote")
        quote_texts = [q.get_text().strip()
                  for q in quotes]
        post_col['quotes'] = quote_texts
        

        
        # Remove quotes from the main HTML, leaving blog author's commentary:
        for q in quotes:
            q.extract()
        
        post_col['editorial_text'] = post.text

        cols += [post_col]

    return cols

# %% [markdown]
# ## Grab All Post URLs from Blog Home Directory, add to MongoDB

# %%
# Use homepage as directory.
blog_home = "https://polyinthemedia.blogspot.com/"
blog_domain = "polyinthemedia.blogspot.com"
blog_soup = make_soup(blog_home)

# %%
archive_links = get_all_a_hrefs(blog_soup, '.archive-list')
month_archives = [x for x in archive_links if is_link_date_archive(x)]
test_month_link = month_archives[0]
print(test_month_link)
# Out:
# http://polyinthemedia.blogspot.com/2017/09/

# %%
all_scraped_posts = []
for i, month_archive in enumerate(month_archives):
    print(f'scraping month archive #{i} of 171')
    permalinks = get_post_permalinks(month_archive)
    print('sample permanlink', permalinks[0])
    print(f"{len(permalinks)} articles to scrape in archive")
    cols = scrape_posts(permalinks)
    print('done with month archive\n')
    all_scraped_posts.extend(cols)
# Out:
# scraping month archive #0 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2017/09/cosmopolitan-follows-up-7-signs-you.html
# 10 articles to scrape in archive
# done with month archive
#
# scraping month archive #1 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2007/06/five-wives-of-maurice-pinder.html
# 7 articles to scrape in archive
# done with month archive
#
# scraping month archive #2 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2015/06/jessica-bennett-talks-back-to-roberts.html
# 13 articles to scrape in archive
# done with month archive
#
# scraping month archive #3 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2015/01/at-home-with-polyamory-profile-of.html
# 9 articles to scrape in archive
# done with month archive
#
# scraping month archive #4 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2012/03/love-without-boundaries-revolutionary.html
# 7 articles to scrape in archive
# done with month archive
#
# scraping month archive #5 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2015/05/legal-group-marriage-date-2040-predicts.html
# 12 articles to scrape in archive
# done with month archive
#
# scraping month archive #6 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2009/04/are-bisexuals-glue-that-holds-poly.html
# 4 articles to scrape in archive
# done with month archive
#
# scraping month archive #7 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2011/07/matt-bullen-unveils-his-poly-awakening.html
# 8 articles to scrape in archive
# done with month archive
#
# scraping month archive #8 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2012/06/showtime-announces-polyamory-tv-series.html
# 6 articles to scrape in archive
# done with month archive
#
# scraping month archive #9 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2006/09/utah-trio-asks-court-to-allow-polygamy.html
# 4 articles to scrape in archive
# done with month archive
#
# scraping month archive #10 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2007/08/shifting-meaning-of-word-polyamory.html
# 7 articles to scrape in archive
# done with month archive
#
# scraping month archive #11 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2018/12/umm-that-article-polyamorous-sex-is_25.html
# 3 articles to scrape in archive
# done with month archive
#
# scraping month archive #12 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2012/01/why-i-wont-bow-to-monogamy.html
# 13 articles to scrape in archive
# done with month archive
#
# scraping month archive #13 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2015/07/is-poly-next-future-marriage-equality.html
# 10 articles to scrape in archive
# done with month archive
#
# scraping month archive #14 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2010/10/south-african-poly-family-profiled.html
# 9 articles to scrape in archive
# done with month archive
#
# scraping month archive #15 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2017/02/about-carrie-jenkins-poly-philosopher.html
# 10 articles to scrape in archive
# done with month archive
#
# scraping month archive #16 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2011/09/future-of-our-defining-word.html
# 5 articles to scrape in archive
# done with month archive
#
# scraping month archive #17 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2009/01/goth-wannabe-and-christian-sexuality.html
# 7 articles to scrape in archive
# done with month archive
#
# scraping month archive #18 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2019/09/nico-tortorella-is-developing-tv-show.html
# 4 articles to scrape in archive
# done with month archive
#
# scraping month archive #19 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2006/07/what-can-top-sliced-bread.html
# 9 articles to scrape in archive
# done with month archive
#
# scraping month archive #20 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2008/06/husband-three-kids-and-two-boyfriends.html
# 8 articles to scrape in archive
# done with month archive
#
# scraping month archive #21 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2011/01/poly-wins-media-notice-in-portugal.html
# 5 articles to scrape in archive
# done with month archive
#
# scraping month archive #22 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2007/07/home-to-mother.html
# 5 articles to scrape in archive
# done with month archive
#
# scraping month archive #23 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2006/04/lets-get-metaphysical.html
# 6 articles to scrape in archive
# done with month archive
#
# scraping month archive #24 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2018/10/a-new-move-to-bring-poly-awareness-to.html
# 6 articles to scrape in archive
# done with month archive
#
# scraping month archive #25 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2011/03/best-poly-parade-float-ever.html
# 9 articles to scrape in archive
# done with month archive
#
# scraping month archive #26 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2012/05/sweet-reward-of-open-loving-but.html
# 6 articles to scrape in archive
# done with month archive
#
# scraping month archive #27 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2006/05/taking-open-relationships-beyond-sex.html
# 6 articles to scrape in archive
# done with month archive
#
# scraping month archive #28 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2006/06/group-wedding-on-new-yorker-cover.html
# 5 articles to scrape in archive
# done with month archive
#
# scraping month archive #29 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2019/10/flamingly-out-and-proud-nico-tortorella.html
# 6 articles to scrape in archive
# done with month archive
#
# scraping month archive #30 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2015/11/no-monique-objects-her-open-marriage-is.html
# 11 articles to scrape in archive
# done with month archive
#
# scraping month archive #31 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2016/02/how-polyamorous-couples-use-google.html
# 10 articles to scrape in archive
# done with month archive
#
# scraping month archive #32 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2018/03/wondering-how-polyamorous-relationships.html
# 7 articles to scrape in archive
# done with month archive
#
# scraping month archive #33 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2019/07/tvs-most-interesting-polyamorous.html
# 4 articles to scrape in archive
# done with month archive
#
# scraping month archive #34 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2014/09/5-lessons-monogamous-families-can-learn.html
# 11 articles to scrape in archive
# done with month archive
#
# scraping month archive #35 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2007/03/in-secret-polygamy-follows-africans-to.html
# 6 articles to scrape in archive
# done with month archive
#
# scraping month archive #36 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2010/12/upside-of-polyamory.html
# 11 articles to scrape in archive
# done with month archive
#
# scraping month archive #37 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2014/11/post-number-1000-poly-being-seen-as.html
# 8 articles to scrape in archive
# done with month archive
#
# scraping month archive #38 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2017/01/openly-poly-candidate-runs-for.html
# 7 articles to scrape in archive
# done with month archive
#
# scraping month archive #39 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2016/03/an-israeli-newspaper-looks-at-poly.html
# 15 articles to scrape in archive
# done with month archive
#
# scraping month archive #40 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2011/08/why-open-marriages-dont-work.html
# 7 articles to scrape in archive
# done with month archive
#
# scraping month archive #41 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2012/11/new-book-poly-activist-meg-barkers.html
# 6 articles to scrape in archive
# done with month archive
#
# scraping month archive #42 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2014
of 171
# sample permanlink http://polyinthemedia.blogspot.com/2012/10/the-showtime-polyamory-series-taking.html
# 6 articles to scrape in archive
# done with month archive
#
# scraping month archive #92 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2016/09/portland-tv.html
# 11 articles to scrape in archive
# done with month archive
#
# scraping month archive #93 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2019/01/tumult-grows-in-israel-over.html
# 5 articles to scrape in archive
# done with month archive
#
# scraping month archive #94 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2008/08/what-has-six-legs-and-scares-some.html
# 6 articles to scrape in archive
# done with month archive
#
# scraping month archive #95 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2009/10/mono-vs-poly-debated-on-cnn-tv.html
# 9 articles to scrape in archive
# done with month archive
#
# scraping month archive #96 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2013/12/the-bright-poly-future-and-some-dark.html
# 16 articles to scrape in archive
# done with month archive
#
# scraping month archive #97 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2015/08/two-new-poly-books-stories-from.html
# 11 articles to scrape in archive
# done with month archive
#
# scraping month archive #98 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2010/04/poly-jewelry-clothing-and-other.html
# 6 articles to scrape in archive
# done with month archive
#
# scraping month archive #99 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2017/05/the-poly-101s-world-is-now-seeing.html
# 7 articles to scrape in archive
# done with month archive
#
# scraping month archive #100 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2018/02/tomorrow-mornings-today-show-will.html
# 9 articles to scrape in archive
# done with month archive
#
# scraping month archive #101 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2010/08/germany-giant-nude-puppy-pile-on.html
# 14 articles to scrape in archive
# done with month archive
#
# scraping month archive #102 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2018/07/a-lesson-on-what-it-means-to-be.html
# 5 articles to scrape in archive
# done with month archive
#
# scraping month archive #103 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2017/06/12-people-explain-how-their-polyamorous.html
# 10 articles to scrape in archive
# done with month archive
#
# scraping month archive #104 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2017/07/new-third-edition-of-ethical-slut.html
# 10 articles to scrape in archive
# done with month archive
#
# scraping month archive #105 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2016/11/a-poly-movement-stirs-in-japan.html
# 11 articles to scrape in archive
# done with month archive
#
# scraping month archive #106 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2005/09/term-of-endearments.html
# 3 articles to scrape in archive
# done with month archive
#
# scraping month archive #107 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2010/09/danish-story.html
# 8 articles to scrape in archive
# done with month archive
#
# scraping month archive #108 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2005/11/stuck-on-youse.html
# 3 articles to scrape in archive
# done with month archive
#
# scraping month archive #109 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2015/02/what-its-like-to-be-polyamorous-genius.html
# 16 articles to scrape in archive
# done with month archive
#
# scraping month archive #110 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2017/08/ad-campaign-for-yoplait-builds-on.html
# 3 articles to scrape in archive
# done with month archive
#
# scraping month archive #111 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2006/12/german-green-endorses-poly-brouhaha.html
# 8 articles to scrape in archive
# done with month archive
#
# scraping month archive #112 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2012/12/lgbtq-mag-profiles-exemplars-of-ethical.html
# 10 articles to scrape in archive
# done with month archive
#
# scraping month archive #113 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2015/04/in-uk-trans-poly-runs-for-parliament.html
# 12 articles to scrape in archive
# done with month archive
#
# scraping month archive #114 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2008/02/internet-pushes-polyamory-to-its.html
# 12 articles to scrape in archive
# done with month archive
#
# scraping month archive #115 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2009/08/yes-we-get-jealous.html
# 6 articles to scrape in archive
# done with month archive
#
# scraping month archive #116 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2008/03/open-relationships-what-world-already.html
# 9 articles to scrape in archive
# done with month archive
#
# scraping month archive #117 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2007/05/upcoming-poly-books-and-movie.html
# 7 articles to scrape in archive
# done with month archive
#
# scraping month archive #118 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2006/02/i-love-you-and-you-and-you-and-you-too.html
# 5 articles to scrape in archive
# done with month archive
#
# scraping month archive #119 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2016/07/why-polyamory-cured-my-jealousy-and.html
# 10 articles to scrape in archive
# done with month archive
#
# scraping month archive #120 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2018/08/time-mag-what-monogamous-couples-can.html
# 2 articles to scrape in archive
# done with month archive
#
# scraping month archive #121 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2010/02/wendy-o-matic-interviewed.html
# 9 articles to scrape in archive
# done with month archive
#
# scraping month archive #122 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2006/11/polygamists-fight-to-be-seen-as-part_27.html
# 8 articles to scrape in archive
# done with month archive
#
# scraping month archive #123 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2013/02/preview-promos-for-our-america-poly.html
# 15 articles to scrape in archive
# done with month archive
#
# scraping month archive #124 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2009/11/love-is-1-man-3-women-and-bed-built-for.html
# 5 articles to scrape in archive
# done with month archive
#
# scraping month archive #125 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2010/03/breaking-upwards-movie-on-negotiating.html
# 14 articles to scrape in archive
# done with month archive
#
# scraping month archive #126 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2016/04/meet-people-in-quads.html
# 11 articles to scrape in archive
# done with month archive
#
# scraping month archive #127 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2017/12/ny-times-better-living-through-music.html
# 8 articles to scrape in archive
# done with month archive
#
# scraping month archive #128 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2019/04/were-moving-from-stage-2-to-stage-3.html
# 3 articles to scrape in archive
# done with month archive
#
# scraping month archive #129 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2008/12/poly-in-mexico-chile-and-brazil.html
# 4 articles to scrape in archive
# done with month archive
#
# scraping month archive #130 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2013/01/more-poly-college-voices.html
# 11 articles to scrape in archive
# done with month archive
#
# scraping month archive #131 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2014/08/all-39-nonfiction-books-on-modern.html
# 12 articles to scrape in archive
# done with month archive
#
# scraping month archive #132 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2007/10/transqueer-triad-meets-tabloid-diet-mag.html
# 6 articles to scrape in archive
# done with month archive
#
# scraping month archive #133 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2017/04/making-gig-out-of-chronicling-your-poly.html
# 6 articles to scrape in archive
# done with month archive
#
# scraping month archive #134 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2019/03/on-opposite-side-of-earth-is-polyamory.html
# 7 articles to scrape in archive
# done with month archive
#
# scraping month archive #135 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2011/11/swedish-academic-argues-for.html
# 10 articles to scrape in archive
# done with month archive
#
# scraping month archive #136 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2007/02/love-triangle-try-hexagon.html
# 5 articles to scrape in archive
# done with month archive
#
# scraping month archive #137 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2007/11/strange-credibility-of-polyamory.html
# 12 articles to scrape in archive
# done with month archive
#
# scraping month archive #138 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2005/10/more-marry-er.html
# 2 articles to scrape in archive
# done with month archive
#
# scraping month archive #139 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2015/12/minxs-top-5-poly-trends-of-2015.html
# 9 articles to scrape in archive
# done with month archive
#
# scraping month archive #140 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2007/01/not-too-emo.html
# 7 articles to scrape in archive
# done with month archive
#
# scraping month archive #141 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2012/07/does-time-magazine-read-polyamory-in.html
# 9 articles to scrape in archive
# done with month archive
#
# scraping month archive #142 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2018/06/that-canadian-polyfamily-with-three.html
# 8 articles to scrape in archive
# done with month archive
#
# scraping month archive #143 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2011/05/its-nots-gay-when-its-in-3-way.html
# 8 articles to scrape in archive
# done with month archive
#
# scraping month archive #144 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2008/10/sartres-play-no-exit-as-poly-fable.html
# 6 articles to scrape in archive
# done with month archive
#
# scraping month archive #145 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2019/02/woke-poly-food-truck-in-news.html
# 8 articles to scrape in archive
# done with month archive
#
# scraping month archive #146 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2016/12/why-poly-is-so-feminist-version-to-give.html
# 7 articles to scrape in archive
# done with month archive
#
# scraping month archive #147 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2009/05/poly-at-kinkglbt-clinicians-conference.html
# 10 articles to scrape in archive
# done with month archive
#
# scraping month archive #148 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2013/09/showtimes-polyamory-episode-7-recap.html
# 12 articles to scrape in archive
# done with month archive
#
# scraping month archive #149 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2016/06/bbc-polyamorous-relationships-may-be.html
# 7 articles to scrape in archive
# done with month archive
#
# scraping month archive #150 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2011/06/how-queer-and-weird-partnerships.html
# 7 articles to scrape in archive
# done with month archive
#
# scraping month archive #151 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2014/10/more-press-about-feminist-poly-origin.html
# 7 articles to scrape in archive
# done with month archive
#
# scraping month archive #152 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2010/11/downsides-of-polyamory.html
# 9 articles to scrape in archive
# done with month archive
#
# scraping month archive #153 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2010/06/open-relationships-you-get-to-make.html
# 6 articles to scrape in archive
# done with month archive
#
# scraping month archive #154 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2012/04/poly-podcasts-and-online-radio.html
# 11 articles to scrape in archive
# done with month archive
#
# scraping month archive #155 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2014/06/10th-circuit-gay-marriage-ruling.html
# 8 articles to scrape in archive
# done with month archive
#
# scraping month archive #156 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2012/08/new-jersey-newspaper-columnist-comes.html
# 10 articles to scrape in archive
# done with month archive
#
# scraping month archive #157 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2008/05/web-comic-begins-poly-saga.html
# 9 articles to scrape in archive
# done with month archive
#
# scraping month archive #158 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2008/09/open-marriages-on-foxs-morning-show.html
# 4 articles to scrape in archive
# done with month archive
#
# scraping month archive #159 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2006/10/poly-love-is.html
# 11 articles to scrape in archive
# done with month archive
#
# scraping month archive #160 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2009/02/morning-shock-jocks-do-stinker.html
# 6 articles to scrape in archive
# done with month archive
#
# scraping month archive #161 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2010/01/many-successful-gay-marriages-share.html
# 7 articles to scrape in archive
# done with month archive
#
# scraping month archive #162 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2008/04/poly-and-bible.html
# 7 articles to scrape in archive
# done with month archive
#
# scraping month archive #163 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2013/08/polyamory-next-step-for-free-love.html
# 11 articles to scrape in archive
# done with month archive
#
# scraping month archive #164 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2017/11/shes-gotta-have-it-spike-lees.html
# 7 articles to scrape in archive
# done with month archive
#
# scraping month archive #165 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2018/01/cosmos-polyamory-diaries-goes-on.html
# 8 articles to scrape in archive
# done with month archive
#
# scraping month archive #166 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2006/03/dont-do-unto-others.html
# 6 articles to scrape in archive
# done with month archive
#
# scraping month archive #167 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2015/03/two-more-kickstarter-movies-monogamish.html
# 12 articles to scrape in archive
# done with month archive
#
# scraping month archive #168 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2009/07/jenny-block-on-aol.html
# 14 articles to scrape in archive
# done with month archive
#
# scraping month archive #169 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2013/03/poly-marriage-or-poly-freedom.html
# 14 articles to scrape in archive
# done with month archive
#
# scraping month archive #170 of 171
# sample permanlink http://polyinthemedia.blogspot.com/2010/05/polyamory-researcher-tells-what-shes.html
# 6 articles to scrape in archive
# done with month archive

# %%
unsouped = []
for post in all_scraped_posts:
    post['raw_post_html'] = str(post['raw_post_html'])
    post['raw_comments_html'] = str(post['raw_comments_html'])
    unsouped += [post]

# %%
pd.DataFrame(unsouped).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 9 columns):
# raw_post_html        1470 non-null object
# raw_comments_html    1470 non-null object
# num_comments         1470 non-null int64
# post_date_string     1470 non-null object
# post_date            1470 non-null datetime64[ns]
# post_title           1470 non-null object
# quotes               1470 non-null object
# editorial_text       1470 non-null object
# _id                  1470 non-null object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 103.5+ KB

# %%
len(all_scraped_posts)
# Out:
# 1470

# %%
all_scraped_posts[0]
# Out:
#  'raw_comments_html': '<div id="comments">\n<a name="comments"></a>\n<h4>0 Comments:</h4>\n<dl id="comments-block">\n</dl>\n<p class="comment-timestamp">\n<a class="comment-link" href="https://www.blogger.com/comment.g?blogID=30436440&amp;postID=2413074731950245844">Post a Comment</a>\n</p>\n<p class="comment-timestamp">\n<a href="http://polyinthemedia.blogspot.com/">&lt;&lt; Home</a>\n</p>\n</div>',
#  'comments': [],
#  'num_comments': 0,
#  'post_date_string': 'September 26, 2017',
#  'post_date': datetime.datetime(2017, 9, 26, 0, 0),
#  'post_title': 'Cosmopolitan follows up: "7 Signs You Might Be Hard-Wired for Monogamy"',
#  'quotes': ['7 Signs You Might Be Hard-Wired for Monogamy\n\n\n\nViktar Salomin / Stocksy\n\nThere are no hard and fast rules, but there are some hints.\n\nBy Sophie Saint Thomas\n\nFrom Broad City to Unicornland, open relationships are appearing more in pop culture. There are many forms of consensual non-monogamy (CNM), ranging from “don’t ask, don’t tell” sexually open relationships to polyamory.... According to Dr. Zhana Vrangalova, a sex educator and adjunct professor in human sexuality at NYU, interest in CNM across the board is rising, but Google searches have especially spiked for polyamory.\n\nWith all the hubbub, if you’re monogamous, you may be wondering if you’re missing out. ... There are some personality traits that may point to the right relationship style for your needs. We spoke with some of the leading sex researchers to talk about indicators that can help you decide. Of course, as all interviewed were quick to add, often exploring is half the fun. ... Just remember to check in with yourself and your partner(s) as you go, and don’t feel bad if regular ole’ monogamy is what you want. I promise you can still be cool. ...\n\n1. A lot of change makes you uncomfortable. Change is inevitable in any relationship. However, in polyamorous relationships, the dynamic between you and your partners is more likely to ebb and flow.... If too much change makes you uneasy, you may be better suited for monogamy. ...\n\n2. You aren’t the best with jealousy. Most people get jealous.... However, the ability to cope well with the emotion, and regulate it rather than lashing out, is a crucial factor in successful polyamorous relationships....\n\n3. You’re not huge on relationship talks. Polyamorous relationships require constant communication around often uncomfortable topics. ...\n\n4. You have stable attachment patterns. This one is a trick; stable relationship patterns are helpful for both polyamorous and monogamous relationships. ... What can mess up any relationship are anxious attachment patterns, when you tend to be clingy and constantly assume your partner’s going to leave you. ...\n\n5. You’re not super organized. ...Most poly problems take place in calendars rather than the bedroom.\n\n6. You prefer living in rural areas. “It’s easier for people who don’t have stigmatized relationships to find belonging and community,” Dr. Zhana says. ... Supportive friends are important for your mental health (and therefore successful romantic relationships). You need someone to bitch to. If you prefer life in rural areas where traditional relationships are the norm, you may be better suited for monogamy.\n\n7. You’re simply uninterested in consensual non-monogamy. ... Go for the relationship style you desire. \n\nDr. Zhana teaches a webinar\xa0that can help people decide if polyamory or monogamy is right for them. Learn more about it\xa0here.'],
#  'editorial_text': '\n\n                      \t \n                      \t Cosmopolitan follows up: "7 Signs You Might Be Hard-Wired for Monogamy"  \n\t                       \n                          \n\n\n"Relationship choice" is the theme that the poly movement\'s activists, movers, and shakers firmly adopted several years ago as their guiding star. Poly is right for some, monogamy is right for others; no shame. The crucial thing is to figure out what\'s right for you, and look for partners who actually match.\n\nWhich means telling about yourself, and asking a new person about their feelings on the matter, very early. And explain exactly what you mean by polyamory, and what version of it draws you, because people often have their own assumptions and misunderstandings of the word.\n\nBut first you need to figure yourself out.\xa0Cosmopolitan,\xa0after its story "How My Poly Relationship Helped Me Make a Difficult Medical Decision" a few days ago,\xa0posts some twists to consider:\n\n\nThe whole article (September 25, 2017).\n\n[Permalink]Labels: monogamy\n\nposted by Alan | \n \n'}

# %%
d = scrape_posts(['https://polyinthemedia.blogspot.com/2012/08/modern-poly-gaining-traction-in-south.html'])[0]
d['editorial_text']
# Out:
# 'Modern poly gaining traction in South Africa\n\t                       \n                          \n\nCity Press (South Africa)The small community of polyfolks in South Africa, a country of 49 million, has shown how dedicated people can spread a compelling idea.Their last media splash was in the South African edition of Cosmopolitan. Now City Press, a mass newspaper (readership 2.5 million) aimed at the country\'s 80% black population, presents a fine poly-profile article by the same writer. It covers all the right bases.Modern, egalitarian, gender-neutral polyamory is a noteworthy introduction to Africa for its contrasts to traditional patriarchal polygamy, an ancient fact of life in many regions. South African President Jacob Zuma, for instance, has four wives. This is legal and is generally considered acceptable or only mildly embarrassing.South Africa is the only country on the continent with a visible polyamory movement as far as I can tell.Read the whole article (July 29, 2012).Update: The article got Christel and Arno a spot on the Redi Tlhabi radio talk show on August 31, airing on TalkRadio 702 in the Johannesburg area and 567 CapeTalk in Capetown. "We definitely kicked ass!" says Christel. Listen here.[Permalink]Labels: South Africa\n\nposted by Alan |'

# %%
d = scrape_posts(['https://polyinthemedia.blogspot.com/2012/08/modern-poly-gaining-traction-in-south.html'])[0]
d['editorial_text']
# Out:
# '\n\n                      \t \n                      \t Modern poly gaining traction in South Africa\n\t                       \n                          \n\nCity Press (South Africa)The small community of polyfolks in South Africa, a country of 49 million, has shown how dedicated people can spread a compelling idea.Their last media splash was in the South African edition of Cosmopolitan. Now City Press, a mass newspaper (readership 2.5 million) aimed at the country\'s 80% black population, presents a fine poly-profile article by the same writer. It covers all the right bases.Modern, egalitarian, gender-neutral polyamory is a noteworthy introduction to Africa for its contrasts to traditional patriarchal polygamy, an ancient fact of life in many regions. South African President Jacob Zuma, for instance, has four wives. This is legal and is generally considered acceptable or only mildly embarrassing.South Africa is the only country on the continent with a visible polyamory movement as far as I can tell.Read the whole article (July 29, 2012).Update: The article got Christel and Arno a spot on the Redi Tlhabi radio talk show on August 31, airing on TalkRadio 702 in the Johannesburg area and 567 CapeTalk in Capetown. "We definitely kicked ass!" says Christel. Listen here.[Permalink]Labels: South Africa\n\nposted by Alan | \n \n'

# %% [markdown]
# ## Load into MongoDB

# %%
db.list_collection_names()
# Out:
# ['subreddit_polyamory',
#  'subreddit_relationships',
#  'temp',
#  'pitm_2',
#  'pitm',
#  'test']

# %%
db.pitm_2.insert_many(all_scraped_posts)
